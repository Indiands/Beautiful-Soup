# %% [markdown]
# # Scrap data from Cricket

# %% [markdown]
# #### Cricket is most watched game after football and very famous in India. Here, we are going to scrap different data from ICC website.

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Q1. Scraping ICC Men's ODI Team and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
page1 = requests.get(url)

# Check the page content
soup = BeautifulSoup(page1.content)

# %% [markdown]
# First we take a instance of 'url' and send request to the webpage. Now, taking our tool 'BeautifulSoup' to parser the content.

# %%
# Scraping the team names
team = soup.find_all('span', class_ = "u-hide-phablet")

# Creating empty list and store data into that
team_name = []
for i in team:
    team_name.append(i.text)

# %% [markdown]
# Here, we scrap 'Team Name' by inspect them from webpage and stored into an empty list.

# %%
# Create empty list and scrap frist element
matches = []
points = []
ratings = []
new_list = []
for i in soup.find_all('td', class_ = "rankings-block__banner--matches"):
    matches.append(i.text)
    
for i in soup.find_all('td', class_ = "rankings-block__banner--points"):
    points.append(i.text)
    
for i in soup.find_all('td', class_ = "rankings-block__banner--rating u-text-right"):
    ratings.append(i.text.replace("\n", ""))
    
# Scraping other teame's number of matches and points:    
for i in soup.find_all('td', class_ = "table-body__cell u-center-text"):
    new_list.append(i.text)

# Scraping other team's matches and points:    
for i in range(0,len(new_list)-1,2):
    matches.append(new_list[i])
    points.append(new_list[i+1])
    
for i in soup.find_all('td', class_ = "table-body__cell u-text-right rating"):
    ratings.append(i.text)

# %% [markdown]
# While scraping data like matches, points etc. we see it contains only 1 information and rest information present into next element. So, solving this problem we scrap two elements of the same purpose. Then append those elements in to empty list.

# %%
print(len(team_name), len(matches), len(points), len(ratings))
# Out:
# 20 20 20 20

# %% [markdown]
# We see our fetched data is in same lenth.

# %% [markdown]
# # Create a DataFrame

# %%
# Creating dataframe with giving column name:
icc_ODI = pd.DataFrame({})
icc_ODI['Team Name'] = team_name
icc_ODI['Matches'] = matches
icc_ODI['Points'] = points
icc_ODI['Ratings'] = ratings
icc_ODI
# Out:
#            Team Name Matches Points  \
# 0            England      27  3,226
# 1        New Zealand      22  2,508
# 2              India      34  3,802
# 3           Pakistan      22  2,354
# 4          Australia      29  3,071
# 5       South Africa      24  2,392
# 6         Bangladesh      30  2,753
# 7          Sri Lanka      29  2,658
# 8        West Indies      41  2,902
# 9        Afghanistan      18  1,238
# 10           Ireland      23  1,214
# 11          Scotland      27  1,254
# 12          Zimbabwe      26  1,098
# 13           Namibia      19    642
# 14       Netherlands      21    673
# 15               UAE      22    697
# 16              Oman      30    919
# 17     United States      27    641
# 18             Nepal      22    331
# 19  Papua New Guinea      26    209
#
#                                               Ratings
# 0                               119               ...
# 1                                                 114
# 2                                                 112
# 3                                                 107
# 4                                                 106
# 5                                                 100
# 6                                                  92
# 7                                                  92
# 8                                                  71
# 9                                                  69
# 10                                                 53
# 11                                                 46
# 12                                                 42
# 13                                                 34
# 14                                                 32
# 15                                                 32
# 16                                                 31
# 17                                                 24
# 18                                                 15
# 19                                                  8

# %%
df = icc_ODI
df.head()
# Out:
#      Team Name Matches Points  \
# 0      England      27  3,226
# 1  New Zealand      22  2,508
# 2        India      34  3,802
# 3     Pakistan      22  2,354
# 4    Australia      29  3,071
#
#                                              Ratings
# 0                              119               ...
# 1                                                114
# 2                                                112
# 3                                                107
# 4                                                106

# %%
df.tail()
# Out:
#            Team Name Matches Points Ratings
# 15               UAE      22    697      32
# 16              Oman      30    919      31
# 17     United States      27    641      24
# 18             Nepal      22    331      15
# 19  Papua New Guinea      26    209       8

# %%
df.sample(5)
# Out:
#            Team Name Matches Points Ratings
# 2              India      34  3,802     112
# 19  Papua New Guinea      26    209       8
# 6         Bangladesh      30  2,753      92
# 7          Sri Lanka      29  2,658      92
# 1        New Zealand      22  2,508     114

# %%
df.describe()
# Out:
#             Team Name Matches Points Ratings
# count              20      20     20      20
# unique             20      12     20      18
# top     United States      22  2,392      92
# freq                1       4      1       2

# %% [markdown]
# # Q2.Scrap ICC Men's ODI Batsmen and create a dataframe

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
page2 = requests.get(url)

# Check page contents
soup = BeautifulSoup(page2.content)

# %%
# Create empty list
players = []
team_name = []
rating = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace("\n", ""))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    

for i in soup.find_all('td', class_ = "table-body__cell rankings-table__name name"):
    for j in i.find_all('a'):
        players.append(j.text)
        
for i in soup.find_all('span', class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)

# %%
print(len(players), len(team_name), len(rating))
# Out:
# 100 100 100

# %% [markdown]
# # Creating Data Frame

# %%
Batsmen = pd.DataFrame({})
Batsmen['Player'] = players
Batsmen['Team'] = team_name
Batsmen['Rating'] = rating
Batsmen
# Out:
#                    Player                     Team Rating
# 0              Babar Azam  PAK                        890
# 1             Imam-ul-Haq                      PAK    779
# 2   Rassie van der Dussen                       SA    766
# 3         Quinton de Kock                       SA    759
# 4          Jonny Bairstow                      ENG    732
# ..                    ...                      ...    ...
# 95        Mohammad Rizwan                      PAK    438
# 96          Steven Taylor                      USA    437
# 97         Mitchell Marsh                      AUS    437
# 98          Matthew Cross                      SCO    436
# 99  Chundangapoyil Rizwan                      UAE    433
#
# [100 rows x 3 columns]

# %%
df = Batsmen
df.head(20)
# Out:
#                    Player                     Team Rating
# 0              Babar Azam  PAK                        890
# 1             Imam-ul-Haq                      PAK    779
# 2   Rassie van der Dussen                       SA    766
# 3         Quinton de Kock                       SA    759
# 4          Jonny Bairstow                      ENG    732
# 5            David Warner                      AUS    725
# 6             Virat Kohli                      IND    722
# 7            Rohit Sharma                      IND    718
# 8             Ross Taylor                       NZ    701
# 9             Steve Smith                      AUS    697
# 10               Joe Root                      ENG    691
# 11           Fakhar Zaman                      PAK    690
# 12        Kane Williamson                       NZ    685
# 13              Shai Hope                       WI    679
# 14            Tamim Iqbal                      BAN    675
# 15              Jason Roy                      ENG    672
# 16         Shikhar Dhawan                      IND    668
# 17          Paul Stirling                      IRE    664
# 18        Mushfiqur Rahim                      BAN    657
# 19             Alex Carey                      AUS    655

# %%
df.tail(20)
# Out:
#                    Player Team Rating
# 80     Niroshan Dickwella   SL    465
# 81            R.K. Paudel  NEP    462
# 82       Mitchell Santner   NZ    462
# 83           Afif Hossain  BAN    459
# 84          Dasun Shanaka   SL    455
# 85    Colin de Grandhomme   NZ    453
# 86         Shamarh Brooks   WI    452
# 87            Rashid Khan  AFG    447
# 88          Michael Leask  SCO    446
# 89          Charles Amini  PNG    444
# 90             Max O'Dowd  NED    443
# 91             Finn Allen   NZ    442
# 92           Sanju Samson  IND    442
# 93           Craig Ervine  ZIM    442
# 94         Muhammad Usman  UAE    440
# 95        Mohammad Rizwan  PAK    438
# 96          Steven Taylor  USA    437
# 97         Mitchell Marsh  AUS    437
# 98          Matthew Cross  SCO    436
# 99  Chundangapoyil Rizwan  UAE    433

# %%
df.sample(10)
# Out:
#                  Player Team Rating
# 87          Rashid Khan  AFG    447
# 44    Najibullah Zadran  AFG    541
# 60        Scott Edwards  NED    504
# 8           Ross Taylor   NZ    701
# 50           Aqib Ilyas  OMA    524
# 73        Soumya Sarkar  BAN    476
# 43  Hashmatullah Shaidi  AFG    544
# 55        Aiden Markram   SA    515
# 76       Sarfaraz Ahmed  PAK    468
# 29           Tom Latham   NZ    613

# %%
df.describe()
# Out:
#                 Player Team Rating
# count              100  100    100
# unique             100   21     84
# top     Janneman Malan   NZ    442
# freq                 1    9      3

# %% [markdown]
# # Q3. Scrape ICC Men's ODI Bowlers and create a data frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
page3 = requests.get(url)

# Check page content
soup = BeautifulSoup(page3.content)

# %%
# Create empty list and scrap frist element
players = []
team_name = []
rating = []
best = []

for i in soup.find_all('div', class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace("\n",""))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all("span", class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace("\n",""))

for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for p in i.find_all('a'):
        players.append(p.text)
        
for i in soup.find_all("td", class_ = "table-body__cell nationality-logo rankings-table__team"):
    team_name.append(i.text.replace("\n",""))
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace("\n",""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create Data Frame

# %%
Bowlers = pd.DataFrame({})
Bowlers['Player'] = players
Bowlers['Team'] = team_name
Bowlers['Rating'] = rating
Bowlers['Best'] = best
Bowlers
# Out:
#               Player                    Team Rating  \
# 0        Trent Boult  NZ                        775
# 1     Josh Hazlewood                     AUS    718
# 2   Mujeeb Ur Rahman                     AFG    676
# 3     Shaheen Afridi                     PAK    661
# 4      Mohammad Nabi                     AFG    657
# ..               ...                     ...    ...
# 95        Khawar Ali                     OMA    398
# 96       Sean Abbott                     AUS    398
# 97      Norman Vanua                     PNG    397
# 98     Jimmy Neesham                      NZ    397
# 99    Logan van Beek                     NED    394
#
#                                                  Best
# 0                                   775 v Australi...
# 1                                   733 v England,...
# 2                                   712 v Ireland,...
# 3                                   688 v West Ind...
# 4                                   657 v Zimbabwe...
# ..                                                ...
# 95                                  401 v Nepal, 0...
# 96                                  398 v New Zeal...
# 97                                  397 v Namibia,...
# 98                                  458 v Banglade...
# 99                                  394 v Pakistan...
#
# [100 rows x 4 columns]

# %%
df = Bowlers
df.head(20)
# Out:
#                Player                    Team Rating  \
# 0         Trent Boult  NZ                        775
# 1      Josh Hazlewood                     AUS    718
# 2    Mujeeb Ur Rahman                     AFG    676
# 3      Shaheen Afridi                     PAK    661
# 4       Mohammad Nabi                     AFG    657
# 5        Mehedi Hasan                     BAN    655
# 6          Matt Henry                      NZ    654
# 7      Mitchell Starc                     AUS    653
# 8         Rashid Khan                     AFG    651
# 9      Jasprit Bumrah                     IND    642
# 10  Mustafizur Rahman                     BAN    640
# 11       Chris Woakes                     ENG    640
# 12       Andy McBrine                     IRE    630
# 13      Kagiso Rabada                      SA    629
# 14         Adam Zampa                     AUS    622
# 15    Shakib Al Hasan                     BAN    619
# 16     Alzarri Joseph                      WI    609
# 17        Pat Cummins                     AUS    600
# 18   Mitchell Santner                      NZ    596
# 19   Yuzvendra Chahal                     IND    586
#
#                                                  Best
# 0                                   775 v Australi...
# 1                                   733 v England,...
# 2                                   712 v Ireland,...
# 3                                   688 v West Ind...
# 4                                   657 v Zimbabwe...
# 5                                   725 v Sri Lank...
# 6                                   691 v Banglade...
# 7                                   783 v New Zeal...
# 8                                   806 v Pakistan...
# 9                                   841 v West Ind...
# 10                                  695 v West Ind...
# 11                                  711 v Sri Lank...
# 12                                  646 v West Ind...
# 13                                  724 v England,...
# 14                                  650 v Pakistan...
# 15                                  717 v Zimbabwe...
# 16                                  623 v New Zeal...
# 17                                  729 v Pakistan...
# 18                                  663 v England,...
# 19                                  730 v New Zeal...

# %%
df.tail(20)
# Out:
#                          Player Team Rating  \
# 80                Nuwan Pradeep   SL    432
# 81  Mohammad Mohammad Saifuddin  BAN    428
# 82            Jeffrey Vandersay   SL    422
# 83                   Assad Vala  PNG    422
# 84               Tendai Chatara  ZIM    417
# 85                Saqib Mahmood  ENG    415
# 86                   Wahab Riaz  PAK    415
# 87                Faheem Ashraf  PAK    413
# 88              Richard Ngarava  ZIM    413
# 89                  Zahoor Khan  UAE    408
# 90                Wayne Parnell   SA    405
# 91                 Akshar Patel  IND    404
# 92                Steven Taylor  USA    403
# 93                Hardik Pandya  IND    402
# 94                   Tom Curran  ENG    399
# 95                   Khawar Ali  OMA    398
# 96                  Sean Abbott  AUS    398
# 97                 Norman Vanua  PNG    397
# 98                Jimmy Neesham   NZ    397
# 99               Logan van Beek  NED    394
#
#                                                  Best
# 80                                  506 v England,...
# 81                                  496 v West Ind...
# 82                                  431 v Australi...
# 83                                  424 v United S...
# 84                                  562 v Ireland,...
# 85                                  454 v Pakistan...
# 86                                  522 v England,...
# 87                                  477 v South Af...
# 88                                  413 v Australi...
# 89                                  417 v Papua Ne...
# 90                                  550 v West Ind...
# 91                                  663 v Australi...
# 92                                  403 v Namibia,...
# 93                                  552 v South Af...
# 94                                  443 v Sri Lank...
# 95                                  401 v Nepal, 0...
# 96                                  398 v New Zeal...
# 97                                  397 v Namibia,...
# 98                                  458 v Banglade...
# 99                                  394 v Pakistan...

# %%
df.sample(10)
# Out:
#                Player Team Rating  \
# 10  Mustafizur Rahman  BAN    640
# 33         Bilal Khan  OMA    532
# 65      Anrich Nortje   SA    450
# 86         Wahab Riaz  PAK    415
# 63         Imad Wasim  PAK    452
# 56       Jason Holder   WI    464
# 3      Shaheen Afridi  PAK    661
# 58        Craig Young  IRE    462
# 36        Tim Southee   NZ    524
# 51        Hamza Tahir  SCO    472
#
#                                                  Best
# 10                                  695 v West Ind...
# 33                                  545 v United S...
# 65                                  459 v England,...
# 86                                  522 v England,...
# 63                                  570 v England,...
# 56                                  486 v Sri Lank...
# 3                                   688 v West Ind...
# 58                                  470 v West Ind...
# 36                                  638 v England,...
# 51                                  484 v Nepal, 1...

# %%
df.iloc[5:17]
# Out:
#                Player Team Rating  \
# 5        Mehedi Hasan  BAN    655
# 6          Matt Henry   NZ    654
# 7      Mitchell Starc  AUS    653
# 8         Rashid Khan  AFG    651
# 9      Jasprit Bumrah  IND    642
# 10  Mustafizur Rahman  BAN    640
# 11       Chris Woakes  ENG    640
# 12       Andy McBrine  IRE    630
# 13      Kagiso Rabada   SA    629
# 14         Adam Zampa  AUS    622
# 15    Shakib Al Hasan  BAN    619
# 16     Alzarri Joseph   WI    609
#
#                                                  Best
# 5                                   725 v Sri Lank...
# 6                                   691 v Banglade...
# 7                                   783 v New Zeal...
# 8                                   806 v Pakistan...
# 9                                   841 v West Ind...
# 10                                  695 v West Ind...
# 11                                  711 v Sri Lank...
# 12                                  646 v West Ind...
# 13                                  724 v England,...
# 14                                  650 v Pakistan...
# 15                                  717 v Zimbabwe...
# 16                                  623 v New Zeal...

# %%
df.loc[:3]
# Out:
#              Player                    Team Rating  \
# 0       Trent Boult  NZ                        775
# 1    Josh Hazlewood                     AUS    718
# 2  Mujeeb Ur Rahman                     AFG    676
# 3    Shaheen Afridi                     PAK    661
#
#                                                 Best
# 0                                  775 v Australi...
# 1                                  733 v England,...
# 2                                  712 v Ireland,...
# 3                                  688 v West Ind...

# %% [markdown]
# # Q4. Scrap ICC Men's All Rounder in ODI and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/all-rounder"
page4 = requests.get(url)

# Check page content
soup = BeautifulSoup(page4.content)

# %%
# Create empty list and store data
players = []
team_name = []
rating = []
best = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace("\n", ""))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all("span", class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace("\n", ""))
    
for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for f in i.find_all("a"):
        players.append(f.text)
        
for i in soup.find_all("span", class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace("\n", ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 20 20 20 20

# %% [markdown]
# # Create a Data Frame

# %%
All_Rounder = pd.DataFrame({})
All_Rounder['Player Name'] = players
All_Rounder['Team Name'] = team_name
All_Rounder['Rating'] = rating
All_Rounder['Best Performance'] = best
All_Rounder
# Out:
#             Player Name                Team Name Rating  \
# 0       Shakib Al Hasan  BAN                        372
# 1         Mohammad Nabi                      AFG    325
# 2           Rashid Khan                      AFG    290
# 3      Mitchell Santner                       NZ    275
# 4         Sikandar Raza                      ZIM    261
# 5       Zeeshan Maqsood                      OMA    238
# 6          Mehedi Hasan                      BAN    238
# 7          Chris Woakes                      ENG    235
# 8         Glenn Maxwell                      AUS    227
# 9            Imad Wasim                      PAK    220
# 10         Andy McBrine                      IRE    218
# 11          Shadab Khan                      PAK    217
# 12           Assad Vala                      PNG    217
# 13  Dhananjaya de Silva                       SL    215
# 14  Colin de Grandhomme                       NZ    214
# 15    Wanindu Hasaranga                       SL    211
# 16       Josh Hazlewood                      AUS    211
# 17        Hardik Pandya                      IND    202
# 18          Trent Boult                       NZ    200
# 19       Alzarri Joseph                       WI    197
#
#                                      Best Performance
# 0                                   453 v Zimbabwe...
# 1                                   349 v Zimbabwe...
# 2                                   359 v Pakistan...
# 3                                   317 v England,...
# 4                                   280 v India, 2...
# 5                                   238 v Nepal, 1...
# 6                                   244 v West Ind...
# 7                                   312 v New Zeal...
# 8                                   350 v England,...
# 9                                   299 v Banglade...
# 10                                  218 v New Zeal...
# 11                                  221 v Netherla...
# 12                                  225 v United S...
# 13                                  220 v Australi...
# 14                                  266 v India, 1...
# 15                                  218 v Australi...
# 16                                  214 v New Zeal...
# 17                                  262 v South Af...
# 18                                  213 v India, 0...
# 19                                  197 v New Zeal...

# %%
df = All_Rounder
df.head(10)
# Out:
#         Player Name                Team Name Rating  \
# 0   Shakib Al Hasan  BAN                        372
# 1     Mohammad Nabi                      AFG    325
# 2       Rashid Khan                      AFG    290
# 3  Mitchell Santner                       NZ    275
# 4     Sikandar Raza                      ZIM    261
# 5   Zeeshan Maqsood                      OMA    238
# 6      Mehedi Hasan                      BAN    238
# 7      Chris Woakes                      ENG    235
# 8     Glenn Maxwell                      AUS    227
# 9        Imad Wasim                      PAK    220
#
#                                     Best Performance
# 0                                  453 v Zimbabwe...
# 1                                  349 v Zimbabwe...
# 2                                  359 v Pakistan...
# 3                                  317 v England,...
# 4                                  280 v India, 2...
# 5                                  238 v Nepal, 1...
# 6                                  244 v West Ind...
# 7                                  312 v New Zeal...
# 8                                  350 v England,...
# 9                                  299 v Banglade...

# %%
df.tail(10)
# Out:
#             Player Name Team Name Rating  \
# 10         Andy McBrine       IRE    218
# 11          Shadab Khan       PAK    217
# 12           Assad Vala       PNG    217
# 13  Dhananjaya de Silva        SL    215
# 14  Colin de Grandhomme        NZ    214
# 15    Wanindu Hasaranga        SL    211
# 16       Josh Hazlewood       AUS    211
# 17        Hardik Pandya       IND    202
# 18          Trent Boult        NZ    200
# 19       Alzarri Joseph        WI    197
#
#                                      Best Performance
# 10                                  218 v New Zeal...
# 11                                  221 v Netherla...
# 12                                  225 v United S...
# 13                                  220 v Australi...
# 14                                  266 v India, 1...
# 15                                  218 v Australi...
# 16                                  214 v New Zeal...
# 17                                  262 v South Af...
# 18                                  213 v India, 0...
# 19                                  197 v New Zeal...

# %%
df.sample(5)
# Out:
#             Player Name Team Name Rating  \
# 10         Andy McBrine       IRE    218
# 13  Dhananjaya de Silva        SL    215
# 1         Mohammad Nabi       AFG    325
# 19       Alzarri Joseph        WI    197
# 18          Trent Boult        NZ    200
#
#                                      Best Performance
# 10                                  218 v New Zeal...
# 13                                  220 v Australi...
# 1                                   349 v Zimbabwe...
# 19                                  197 v New Zeal...
# 18                                  213 v India, 0...

# %% [markdown]
# # Q5. Scrap ICC ODI Women's Team and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
page5 = requests.get(url)

# Check page content
soup = BeautifulSoup(page5.content)

# %%
# Scrap Team Name
team = soup.find_all('span', class_ = "u-hide-phablet")

# Create empty list and store first team name into that
womens_team = []
for i in team:
    womens_team.append(i.text)

# %%
# Create empty list and store data into that
match = []
points = []
rating = []
new_list = []

for i in soup.find_all('td', class_ = "rankings-block__banner--matches"):
    match.append(i.text)
    
for i in soup.find_all('td', class_ = "rankings-block__banner--points"):
    points.append(i.text)
    
for i in soup.find_all('td', class_ = "rankings-block__banner--rating u-text-right"):
    rating.append(i.text.replace("\n", ""))
    
for i in soup.find_all('td', class_ = "table-body__cell u-center-text"):
    new_list.append(i.text)
    
# Scrap more details
    
for i in range(0, len(new_list)-1,2):
    match.append(new_list[i])
    points.append(new_list[i+1])
    
for i in soup.find_all('td', class_ = "table-body__cell u-text-right rating"):
    rating.append(i.text)

# %%
print(len(womens_team), len(match), len(points), len(rating))
# Out:
# 11 11 11 11

# %% [markdown]
# # Create DataFrame

# %%
womens_icc = pd.DataFrame({})
womens_icc['Team'] = womens_team
womens_icc['Matches'] = match
womens_icc['Points'] = points
womens_icc['Ratings'] = rating
womens_icc
# Out:
#             Team Matches Points  \
# 0      Australia      18  3,061
# 1   South Africa      26  3,098
# 2        England      25  2,904
# 3          India      27  2,820
# 4    New Zealand      24  2,425
# 5    West Indies      24  2,334
# 6     Bangladesh      12    932
# 7       Pakistan      21  1,237
# 8        Ireland      11    516
# 9      Sri Lanka       8    353
# 10      Zimbabwe       8      0
#
#                                               Ratings
# 0                               170               ...
# 1                                                 119
# 2                                                 116
# 3                                                 104
# 4                                                 101
# 5                                                  97
# 6                                                  78
# 7                                                  59
# 8                                                  47
# 9                                                  44
# 10                                                  0

# %% [markdown]
# # Q6. Scrap ICC Women's ODI players(Batting) and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
page6 = requests.get(url)

# Check page content
soup = BeautifulSoup(page6.content)

# %%
# Create empty list and store data 
players = []
team_name = []
rating = []
best = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all('div', class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all('div', class_ = 'rankings-block__banner--rating'):
    rating.append(i.text)
    
for i in soup.find_all('span', class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace('\n', ''))
    
for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for k in i.find_all("a"):
        players.append(k.text)
        
for i in soup.find_all("span", class_ = "table-body__logo-text"):
    team_name.append(i.text.replace("\n", ""))
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace("\n", ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create DataFrame

# %%
Top_women_players = pd.DataFrame({})
Top_women_players['Players Name'] = players
Top_women_players['Team'] = team_name
Top_women_players['Rating'] = rating
Top_women_players['Players Best'] = best
Top_women_players
# Out:
#            Players Name                     Team Rating  \
# 0          Alyssa Healy  AUS                        785
# 1           Beth Mooney                      AUS    749
# 2       Laura Wolvaardt                       SA    732
# 3        Natalie Sciver                      ENG    725
# 4      Harmanpreet Kaur                      IND    716
# ..                  ...                      ...    ...
# 95        Hayley Jensen                       NZ    212
# 96  Frederique Overdijk                      NED    210
# 97    Jemimah Rodriques                      IND    210
# 98   Anushka Sanjeewani                       SL    209
# 99         Meghna Singh                      IND    208
#
#                                          Players Best
# 0                                   785 v England,...
# 1                                   748 v England,...
# 2                                   741 v Australi...
# 3                                   755 v South Af...
# 4                                   731 v England,...
# ..                                                ...
# 95                                  271 v England,...
# 96                                  210 v Ireland,...
# 97                                  411 v West Ind...
# 98                                  222 v Australi...
# 99                                  212 v England,...
#
# [100 rows x 4 columns]

# %%
df = Top_women_players
df.head(20)
# Out:
#             Players Name                     Team Rating  \
# 0           Alyssa Healy  AUS                        785
# 1            Beth Mooney                      AUS    749
# 2        Laura Wolvaardt                       SA    732
# 3         Natalie Sciver                      ENG    725
# 4       Harmanpreet Kaur                      IND    716
# 5        Smriti Mandhana                      IND    714
# 6            Meg Lanning                      AUS    710
# 7         Rachael Haynes                      AUS    701
# 8      Amy Satterthwaite                       NZ    661
# 9    Chamari Athapaththu                       SL    655
# 10          Ellyse Perry                      AUS    642
# 11        Tammy Beaumont                      ENG    609
# 12        Deandra Dottin                       WI    607
# 13       Stafanie Taylor                       WI    606
# 14           Amelia Kerr                       NZ    601
# 15        Marizanne Kapp                       SA    585
# 16        Heather Knight                      ENG    573
# 17       Hayley Matthews                       WI    567
# 18  Chloe-Lesleigh Tryon                       SA    557
# 19         Sophie Devine                       NZ    557
#
#                                          Players Best
# 0                                   785 v England,...
# 1                                   748 v England,...
# 2                                   741 v Australi...
# 3                                   755 v South Af...
# 4                                   731 v England,...
# 5                                   797 v England,...
# 6                                   834 v New Zeal...
# 7                                   713 v West Ind...
# 8                                   756 v Australi...
# 9                                   691 v South Af...
# 10                                  766 v West Ind...
# 11                                  791 v India, 2...
# 12                                  650 v New Zeal...
# 13                                  766 v Pakistan...
# 14                                  607 v West Ind...
# 15                                  585 v England,...
# 16                                  693 v West Ind...
# 17                                  591 v India, 1...
# 18                                  557 v England,...
# 19                                  678 v Australi...

# %%
df.tail(10)
# Out:
#            Players Name Team Rating  \
# 90       Kyshona Knight   WI    226
# 91         Tazmin Brits   SA    224
# 92      Josephine Nkomo  ZIM    222
# 93  Rajeshwari Gayakwad  IND    215
# 94      Sophie MacMahon  IRE    213
# 95        Hayley Jensen   NZ    212
# 96  Frederique Overdijk  NED    210
# 97    Jemimah Rodriques  IND    210
# 98   Anushka Sanjeewani   SL    209
# 99         Meghna Singh  IND    208
#
#                                          Players Best
# 90                                  379 v Pakistan...
# 91                                  291 v West Ind...
# 92                                  267 v Ireland,...
# 93                                  229 v South Af...
# 94                                  225 v South Af...
# 95                                  271 v England,...
# 96                                  210 v Ireland,...
# 97                                  411 v West Ind...
# 98                                  222 v Australi...
# 99                                  212 v England,...

# %%
df.sample(20)
# Out:
#             Players Name Team Rating  \
# 90        Kyshona Knight   WI    226
# 62          Salma Khatun  BAN    323
# 81       Murshida Khatun  BAN    252
# 36        Yastika Bhatia  IND    426
# 82       Shamima Sultana  BAN    248
# 39              Nida Dar  PAK    411
# 66        Chedean Nation   WI    307
# 13       Stafanie Taylor   WI    606
# 17       Hayley Matthews   WI    567
# 61        Charlotte Dean  ENG    325
# 5        Smriti Mandhana  IND    714
# 92       Josephine Nkomo  ZIM    222
# 35           Sidra Ameen  PAK    445
# 93   Rajeshwari Gayakwad  IND    215
# 53       Brooke Halliday   NZ    347
# 2        Laura Wolvaardt   SA    732
# 30          Maddie Green   NZ    476
# 15        Marizanne Kapp   SA    585
# 65          Andrie Steyn   SA    311
# 18  Chloe-Lesleigh Tryon   SA    557
#
#                                          Players Best
# 90                                  379 v Pakistan...
# 62                                  366 v South Af...
# 81                                  308 v Zimbabwe...
# 36                                  441 v England,...
# 82                                  248 v England,...
# 39                                  426 v Sri Lank...
# 66                                  385 v England,...
# 13                                  766 v Pakistan...
# 17                                  591 v India, 1...
# 61                                  325 v India, 2...
# 5                                   797 v England,...
# 92                                  267 v Ireland,...
# 35                                  443 v Sri Lank...
# 93                                  229 v South Af...
# 53                                  449 v England,...
# 2                                   741 v Australi...
# 30                                  487 v West Ind...
# 15                                  585 v England,...
# 65                                  378 v Ireland,...
# 18                                  557 v England,...

# %%
df.iloc[45:75]
# Out:
#             Players Name Team Rating  \
# 45          Lara Goodall   SA    394
# 46        Nilakshi Silva   SL    384
# 47          Javeria Khan  PAK    382
# 48       Pooja Vastrakar  IND    380
# 49             Leah Paul  IRE    377
# 50    Shemaine Campbelle   WI    366
# 51      Dane van Niekerk   SA    363
# 52       Katherine Brunt  ENG    356
# 53       Brooke Halliday   NZ    347
# 54           Lauren Down   NZ    346
# 55           Muneeba Ali  PAK    346
# 56             Emma Lamb  ENG    343
# 57            Amy Hunter  IRE    343
# 58         Jess Jonassen  AUS    340
# 59         Nigar Sultana  BAN    339
# 60         Sharmin Supta  BAN    331
# 61        Charlotte Dean  ENG    325
# 62          Salma Khatun  BAN    323
# 63       Lauren Winfield  ENG    315
# 64         Trisha Chetty   SA    314
# 65          Andrie Steyn   SA    311
# 66        Chedean Nation   WI    307
# 67        Jhulan Goswami  IND    307
# 68           Richa Ghosh  IND    302
# 69           Lata Mondal  BAN    301
# 70  Prasadani Weerakkody   SL    298
# 71         Katie Perkins   NZ    284
# 72      Orla Prendergast  IRE    275
# 73          Nicola Carey  AUS    274
# 74     Sophie Ecclestone  ENG    272
#
#                                          Players Best
# 45                                  400 v Ireland,...
# 46                                  384 v India, 0...
# 47                                  573 v South Af...
# 48                                  380 v England,...
# 49                                  377 v Netherla...
# 50                                  404 v Banglade...
# 51                                  677 v Sri Lank...
# 52                                  439 v Australi...
# 53                                  449 v England,...
# 54                                  346 v West Ind...
# 55                                  348 v Sri Lank...
# 56                                  343 v India, 2...
# 57                                  343 v Netherla...
# 58                                  410 v West Ind...
# 59                                  338 v West Ind...
# 60                                  330 v England,...
# 61                                  325 v India, 2...
# 62                                  366 v South Af...
# 63                                  422 v Australi...
# 64                                  585 v Ireland,...
# 65                                  378 v Ireland,...
# 66                                  385 v England,...
# 67                                  430 v New Zeal...
# 68                                  376 v England,...
# 69                                  352 v India, 1...
# 70                                  453 v Pakistan...
# 71                                  503 v South Af...
# 72                                  275 v Netherla...
# 73                                  317 v India, 2...
# 74                                  291 v India, 1...

# %%
df.isnull()
# Out:
#     Players Name   Team  Rating  Players Best
# 0          False  False   False         False
# 1          False  False   False         False
# 2          False  False   False         False
# 3          False  False   False         False
# 4          False  False   False         False
# ..           ...    ...     ...           ...
# 95         False  False   False         False
# 96         False  False   False         False
# 97         False  False   False         False
# 98         False  False   False         False
# 99         False  False   False         False
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q7. Scrap ICC Women's ODI all rounder and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"
page7 = requests.get(url)

# Check page content
soup = BeautifulSoup(page7.content)

# %%
# Create empty list and store data into the list:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all("span", class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace("\n", ""))
    
for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for j in i.find_all("a"):
        players.append(j.text)
        
for i in soup.find_all("span", class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace("\n", ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 20 20 20 20

# %% [markdown]
# # Create a DataFrame

# %%
all_rounder = pd.DataFrame({})
all_rounder['Players Name'] = players
all_rounder['Team'] = team_name
all_rounder['Rating'] = rating
all_rounder['Best Performance'] = best
all_rounder
# Out:
#             Players Name                    Team Rating  \
# 0        Hayley Matthews  WI                        380
# 1           Ellyse Perry                     AUS    374
# 2         Natalie Sciver                     ENG    357
# 3            Amelia Kerr                      NZ    356
# 4         Marizanne Kapp                      SA    349
# 5          Deepti Sharma                     IND    322
# 6       Ashleigh Gardner                     AUS    270
# 7          Jess Jonassen                     AUS    246
# 8         Jhulan Goswami                     IND    214
# 9        Katherine Brunt                     ENG    207
# 10     Sophie Ecclestone                     ENG    201
# 11          Rumana Ahmed                     BAN    201
# 12              Nida Dar                     PAK    200
# 13  Chloe-Lesleigh Tryon                      SA    197
# 14       Stafanie Taylor                      WI    192
# 15         Sophie Devine                      NZ    189
# 16          Salma Khatun                     BAN    178
# 17   Chamari Athapaththu                      SL    178
# 18        Charlotte Dean                     ENG    175
# 19             Sune Luus                      SA    171
#
#                                      Best Performance
# 0                                   380 v New Zeal...
# 1                                   548 v West Ind...
# 2                                   395 v South Af...
# 3                                   356 v West Ind...
# 4                                   419 v West Ind...
# 5                                   397 v South Af...
# 6                                   279 v West Ind...
# 7                                   308 v West Ind...
# 8                                   308 v Australi...
# 9                                   296 v Australi...
# 10                                  217 v South Af...
# 11                                  198 v South Af...
# 12                                  206 v Sri Lank...
# 13                                  197 v England,...
# 14                                  559 v New Zeal...
# 15                                  305 v Australi...
# 16                                  170 v Australi...
# 17                                  187 v South Af...
# 18                                  175 v India, 2...
# 19                                  223 v Ireland,...

# %%
df = all_rounder
df.head()
# Out:
#       Players Name                    Team Rating  \
# 0  Hayley Matthews  WI                        380
# 1     Ellyse Perry                     AUS    374
# 2   Natalie Sciver                     ENG    357
# 3      Amelia Kerr                      NZ    356
# 4   Marizanne Kapp                      SA    349
#
#                                     Best Performance
# 0                                  380 v New Zeal...
# 1                                  548 v West Ind...
# 2                                  395 v South Af...
# 3                                  356 v West Ind...
# 4                                  419 v West Ind...

# %%
df.tail()
# Out:
#            Players Name Team Rating  \
# 15        Sophie Devine   NZ    189
# 16         Salma Khatun  BAN    178
# 17  Chamari Athapaththu   SL    178
# 18       Charlotte Dean  ENG    175
# 19            Sune Luus   SA    171
#
#                                      Best Performance
# 15                                  305 v Australi...
# 16                                  170 v Australi...
# 17                                  187 v South Af...
# 18                                  175 v India, 2...
# 19                                  223 v Ireland,...

# %%
df.sample(5)
# Out:
#          Players Name                    Team Rating  \
# 10  Sophie Ecclestone                     ENG    201
# 0     Hayley Matthews  WI                        380
# 11       Rumana Ahmed                     BAN    201
# 14    Stafanie Taylor                      WI    192
# 19          Sune Luus                      SA    171
#
#                                      Best Performance
# 10                                  217 v South Af...
# 0                                   380 v New Zeal...
# 11                                  198 v South Af...
# 14                                  559 v New Zeal...
# 19                                  223 v Ireland,...

# %%
df.iloc[-7:]
# Out:
#             Players Name Team Rating  \
# 13  Chloe-Lesleigh Tryon   SA    197
# 14       Stafanie Taylor   WI    192
# 15         Sophie Devine   NZ    189
# 16          Salma Khatun  BAN    178
# 17   Chamari Athapaththu   SL    178
# 18        Charlotte Dean  ENG    175
# 19             Sune Luus   SA    171
#
#                                      Best Performance
# 13                                  197 v England,...
# 14                                  559 v New Zeal...
# 15                                  305 v Australi...
# 16                                  170 v Australi...
# 17                                  187 v South Af...
# 18                                  175 v India, 2...
# 19                                  223 v Ireland,...

# %%
df.notnull()
# Out:
#     Players Name  Team  Rating  Best Performance
# 0           True  True    True              True
# 1           True  True    True              True
# 2           True  True    True              True
# 3           True  True    True              True
# 4           True  True    True              True
# 5           True  True    True              True
# 6           True  True    True              True
# 7           True  True    True              True
# 8           True  True    True              True
# 9           True  True    True              True
# 10          True  True    True              True
# 11          True  True    True              True
# 12          True  True    True              True
# 13          True  True    True              True
# 14          True  True    True              True
# 15          True  True    True              True
# 16          True  True    True              True
# 17          True  True    True              True
# 18          True  True    True              True
# 19          True  True    True              True

# %% [markdown]
# # Q8. Scrap ICC Men's T20 Team and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/t20i"
page8 = requests.get(url)

# Check page content
soup = BeautifulSoup(page8.content)

# %%
# Scrap Team Name:
team = soup.find_all("span", class_ = "u-hide-phablet")

team_name = []
for i in team:
    team_name.append(i.text)

# %%
# Create empty list and store data into that list:
matches = []
points = []
rating = []
new_list = []

for i in soup.find_all("td", class_ = "rankings-block__banner--matches"):
    matches.append(i.text)
    
for i in soup.find_all("td", class_ = "rankings-block__banner--points"):
    points.append(i.text)
    
for i in soup.find_all("td", class_ = "rankings-block__banner--rating u-text-right"):
    rating.append(i.text.replace("\n", ""))
    
for i in soup.find_all("td", class_ = "table-body__cell u-center-text"):
    new_list.append(i.text)
    
for i in range(0,len(new_list)-1,2):
    matches.append(new_list[i])
    points.append(new_list[i+1])
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right rating"):
    rating.append(i.text)

# %%
print(len(team_name), len(matches), len(points), len(rating))
# Out:
# 84 84 84 84

# %% [markdown]
# # Create a Data Frame

# %%
T20_team = pd.DataFrame({})
T20_team['T20 Team'] = team_name
T20_team['Matches'] = matches
T20_team['Points'] = points
T20_team['Rating'] = rating
T20_team
# Out:
#         T20 Team Matches  Points  \
# 0          India      58  15,556
# 1        England      45  11,814
# 2   South Africa      39  10,135
# 3       Pakistan      51  13,067
# 4    New Zealand      46  11,663
# ..           ...     ...     ...
# 79       Estonia      12       0
# 80       Lesotho       6       0
# 81      Eswatini      11       0
# 82      Thailand      10       0
# 83        Turkey       6       0
#
#                                                Rating
# 0                               268               ...
# 1                                                 263
# 2                                                 260
# 3                                                 256
# 4                                                 254
# ..                                                ...
# 79                                                  0
# 80                                                  0
# 81                                                  0
# 82                                                  0
# 83                                                  0
#
# [84 rows x 4 columns]

# %%
df = T20_team
df.head(20)
# Out:
#             T20 Team Matches  Points  \
# 0              India      58  15,556
# 1            England      45  11,814
# 2       South Africa      39  10,135
# 3           Pakistan      51  13,067
# 4        New Zealand      46  11,663
# 5          Australia      45  11,304
# 6        West Indies      51  12,039
# 7          Sri Lanka      49  11,520
# 8         Bangladesh      49  10,908
# 9        Afghanistan      29   6,312
# 10          Zimbabwe      44   8,669
# 11           Ireland      53  10,101
# 12               UAE      29   5,298
# 13           Namibia      32   5,846
# 14          Scotland      24   4,373
# 15             Nepal      30   5,387
# 16       Netherlands      30   5,157
# 17              Oman      19   3,238
# 18  Papua New Guinea      24   3,495
# 19            Canada      17   2,176
#
#                                                Rating
# 0                               268               ...
# 1                                                 263
# 2                                                 260
# 3                                                 256
# 4                                                 254
# 5                                                 251
# 6                                                 236
# 7                                                 235
# 8                                                 223
# 9                                                 218
# 10                                                197
# 11                                                191
# 12                                                183
# 13                                                183
# 14                                                182
# 15                                                180
# 16                                                172
# 17                                                170
# 18                                                146
# 19                                                128

# %%
df.tail(20)
# Out:
#       T20 Team Matches Points Rating
# 64      Cyprus      11    283     26
# 65     Bahamas      11    260     24
# 66     Hungary      16    358     22
# 67      Belize       6    132     22
# 68      Panama       6    125     21
# 69  Mozambique      15    303     20
# 70      Rwanda      12    215     18
# 71      Serbia      17    184     11
# 72  Seychelles       6     54      9
# 73    Bulgaria      34    296      9
# 74    Maldives      15     81      5
# 75       Samoa       8     42      5
# 76   Gibraltar      21     68      3
# 77      Greece       9     27      3
# 78    Cameroon       7      0      0
# 79     Estonia      12      0      0
# 80     Lesotho       6      0      0
# 81    Eswatini      11      0      0
# 82    Thailand      10      0      0
# 83      Turkey       6      0      0

# %%
df.sample(10)
# Out:
#         T20 Team Matches  Points Rating
# 45      Portugal      11     644     59
# 4    New Zealand      46  11,663    254
# 41       Austria      26   1,686     65
# 66       Hungary      16     358     22
# 2   South Africa      39  10,135    260
# 44       Vanuatu      11     645     59
# 14      Scotland      24   4,373    182
# 53         Ghana      16     659     41
# 70        Rwanda      12     215     18
# 16   Netherlands      30   5,157    172

# %%
df.iloc[55:75]
# Out:
#           T20 Team Matches Points Rating
# 55  Czech Republic      28  1,137     41
# 56       Indonesia       7    265     38
# 57     Switzerland      11    396     36
# 58           Malta      33  1,179     36
# 59           Japan       7    236     34
# 60      Luxembourg      23    774     34
# 61    Sierra Leone      10    331     33
# 62          Bhutan       8    239     30
# 63            Fiji       6    177     30
# 64          Cyprus      11    283     26
# 65         Bahamas      11    260     24
# 66         Hungary      16    358     22
# 67          Belize       6    132     22
# 68          Panama       6    125     21
# 69      Mozambique      15    303     20
# 70          Rwanda      12    215     18
# 71          Serbia      17    184     11
# 72      Seychelles       6     54      9
# 73        Bulgaria      34    296      9
# 74        Maldives      15     81      5

# %%
df.describe()
# Out:
#        T20 Team Matches Points Rating
# count        84      84     84     84
# unique       84      33     79     64
# top         UAE       6      0      0
# freq          1       8      6      6

# %% [markdown]
# # Q9. Scrap ICC Men's T20 Players(Batsman) and Create a Data Frame

# %%
# Scrap get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/t20i/batting"
page9 = requests.get(url)

# Check page content
soup = BeautifulSoup(page9.content)

# %%
# Create empty list and store data into that list:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all("span", class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace('\n', ''))
    
for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for j in i.find_all("a"):
        players.append(j.text)
        
for i in soup.find_all("span", class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace('\n', ''))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create a Data Frame

# %%
T20_players = pd.DataFrame({})
T20_players['T20 Players'] = players
T20_players['Team Name'] = team_name
T20_players['Rating'] = rating
T20_players['Best Performance'] = best
df = T20_players
df
# Out:
#          T20 Players                Team Name Rating  \
# 0   Suryakumar Yadav  IND                        863
# 1    Mohammad Rizwan                      PAK    842
# 2       Devon Conway                       NZ    792
# 3         Babar Azam                      PAK    780
# 4      Aiden Markram                       SA    767
# ..               ...                      ...    ...
# 95         Ryan Burl                      ZIM    375
# 96    Muhammad Usman                      UAE    375
# 97   Shimron Hetmyer                       WI    374
# 98      Norman Vanua                      PNG    371
# 99      Bas de Leede                      NED    370
#
#                                      Best Performance
# 0                                   863 v South Af...
# 1                                   875 v England,...
# 2                                   831 v Australi...
# 3                                   896 v England,...
# 4                                   796 v England,...
# ..                                                ...
# 95                                  407 v Ireland,...
# 96                                  490 v Canada, ...
# 97                                  481 v Australi...
# 98                                  422 v Singapor...
# 99                                  390 v Sri Lank...
#
# [100 rows x 4 columns]

# %%
df.head(20)
# Out:
#            T20 Players                Team Name Rating  \
# 0     Suryakumar Yadav  IND                        863
# 1      Mohammad Rizwan                      PAK    842
# 2         Devon Conway                       NZ    792
# 3           Babar Azam                      PAK    780
# 4        Aiden Markram                       SA    767
# 5          Dawid Malan                      ENG    743
# 6       Glenn Phillips                       NZ    703
# 7        Rilee Rossouw                       SA    689
# 8          Aaron Finch                      AUS    687
# 9          Virat Kohli                      IND    638
# 10     Quinton de Kock                       SA    631
# 11     Pathum Nissanka                       SL    628
# 12     Muhammad Waseem                      UAE    626
# 13         Jos Buttler                      ENG    617
# 14        Rohit Sharma                      IND    601
# 15     Reeza Hendricks                       SA    591
# 16  Rahmanullah Gurbaz                      AFG    587
# 17      Martin Guptill                       NZ    587
# 18        Brandon King                       WI    583
# 19     Nicholas Pooran                       WI    582
#
#                                      Best Performance
# 0                                   863 v South Af...
# 1                                   875 v England,...
# 2                                   831 v Australi...
# 3                                   896 v England,...
# 4                                   796 v England,...
# 5                                   915 v South Af...
# 6                                   703 v England,...
# 7                                   692 v Banglade...
# 8                                   900 v Zimbabwe...
# 9                                   897 v England,...
# 10                                  671 v Sri Lank...
# 11                                  698 v Pakistan...
# 12                                  703 v Singapor...
# 13                                  674 v New Zeal...
# 14                                  718 v West Ind...
# 15                                  647 v Sri Lank...
# 16                                  620 v Zimbabwe...
# 17                                  793 v South Af...
# 18                                  585 v New Zeal...
# 19                                  667 v Banglade...

# %%
df.tail(20)
# Out:
#             T20 Players Team Name Rating  \
# 80        Sean Williams       ZIM    411
# 81        Calum MacLeod       SCO    410
# 82            J.J. Smit       NAM    409
# 83          Usman Ghani       AFG    407
# 84        Matthew Cross       SCO    404
# 85        Sikandar Raza       ZIM    404
# 86  Dhananjaya de Silva        SL    401
# 87          Kamran Khan       QAT    398
# 88             Sese Bau       PNG    393
# 89        Stephan Baard       NAM    389
# 90          Chirag Suri       UAE    389
# 91        Jimmy Neesham        NZ    388
# 92      Vriitya Aravind       UAE    386
# 93         Craig Ervine       ZIM    384
# 94         Harry Tector       IRE    378
# 95            Ryan Burl       ZIM    375
# 96       Muhammad Usman       UAE    375
# 97      Shimron Hetmyer        WI    374
# 98         Norman Vanua       PNG    371
# 99         Bas de Leede       NED    370
#
#                                      Best Performance
# 80                                  481 v Ireland,...
# 81                                  488 v Bermuda,...
# 82                                  425 v Sri Lank...
# 83                                  426 v Oman, 29...
# 84                                  478 v Zimbabwe...
# 85                                  430 v Scotland...
# 86                                  401 v Afghanis...
# 87                                  463 v Bahrain,...
# 88                                  427 v Uganda, ...
# 89                                  440 v Uganda, ...
# 90                                  466 v Germany,...
# 91                                  409 v West Ind...
# 92                                  423 v Singapor...
# 93                                  424 v Namibia,...
# 94                                  416 v Afghanis...
# 95                                  407 v Ireland,...
# 96                                  490 v Canada, ...
# 97                                  481 v Australi...
# 98                                  422 v Singapor...
# 99                                  390 v Sri Lank...

# %%
df.sample(10)
# Out:
#            T20 Players Team Name Rating  \
# 68       Hardik Pandya       IND    441
# 69       Lorcan Tucker       IRE    440
# 96      Muhammad Usman       UAE    375
# 71          Alex Hales       ENG    440
# 10     Quinton de Kock        SA    631
# 12     Muhammad Waseem       UAE    626
# 14        Rohit Sharma       IND    601
# 5          Dawid Malan       ENG    743
# 25  Richard Berrington       SCO    558
# 23       George Munsey       SCO    572
#
#                                      Best Performance
# 68                                  455 v Pakistan...
# 69                                  440 v Australi...
# 96                                  490 v Canada, ...
# 71                                  866 v India, 0...
# 10                                  671 v Sri Lank...
# 12                                  703 v Singapor...
# 14                                  718 v West Ind...
# 5                                   915 v South Af...
# 25                                  587 v Oman, 21...
# 23                                  600 v Netherla...

# %% [markdown]
# # Q10. Scrap ICC Men's T20 Bowler and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/t20i/bowling"
page10 = requests.get(url)

# Check page content
soup = BeautifulSoup(page10.content)

# %%
# Create empty list and store data:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all("div", class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all("div", class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace("\n", ""))
    
for i in soup.find_all("div", class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all("span", class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace("\n", ""))
    
for i in soup.find_all("td", class_ = "table-body__cell rankings-table__name name"):
    for k in i.find_all("a"):
        players.append(k.text)
        
for i in soup.find_all("span", class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all("td", class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace("\n", ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create a Data Frame

# %%
T20_bowler = pd.DataFrame({})
T20_bowler['Players Name'] = players
T20_bowler['Team Name'] = team_name
T20_bowler['Rating'] = rating
T20_bowler['Best Performance'] = best
T20_bowler
# Out:
#             Players Name                Team Name Rating  \
# 0            Rashid Khan  AFG                        700
# 1      Wanindu Hasaranga                       SL    697
# 2         Tabraiz Shamsi                       SA    694
# 3         Josh Hazlewood                      AUS    692
# 4       Mujeeb Ur Rahman                      AFG    687
# ..                   ...                      ...    ...
# 95  Roelof van der Merwe                      NED    391
# 96          Fabian Allen                       WI    387
# 97          Nathan Ellis                      AUS    384
# 98        Barry McCarthy                      IRE    384
# 99         Sean Williams                      ZIM    384
#
#                                      Best Performance
# 0                                   816 v Banglade...
# 1                                   797 v West Ind...
# 2                                   821 v West Ind...
# 3                                   806 v Sri Lank...
# 4                                   745 v Ireland,...
# ..                                                ...
# 95                                  516 v Papua Ne...
# 96                                  625 v Australi...
# 97                                  404 v England,...
# 98                                  384 v Australi...
# 99                                  506 v Afghanis...
#
# [100 rows x 4 columns]

# %%
df = T20_bowler
df.head(20)
# Out:
#            Players Name                Team Name Rating  \
# 0           Rashid Khan  AFG                        700
# 1     Wanindu Hasaranga                       SL    697
# 2        Tabraiz Shamsi                       SA    694
# 3        Josh Hazlewood                      AUS    692
# 4      Mujeeb Ur Rahman                      AFG    687
# 5            Sam Curran                      ENG    665
# 6            Adam Zampa                      AUS    662
# 7         Anrich Nortje                       SA    655
# 8    Maheesh Theekshana                       SL    653
# 9      Mitchell Santner                       NZ    651
# 10    Bhuvneshwar Kumar                      IND    649
# 11          Adil Rashid                      ENG    646
# 12          Trent Boult                       NZ    646
# 13       Keshav Maharaj                       SA    641
# 14         Akeal Hosein                       WI    637
# 15          Tim Southee                       NZ    636
# 16           Haris Rauf                      PAK    632
# 17  Ravichandran Ashwin                      IND    627
# 18          Shadab Khan                      PAK    624
# 19         Reece Topley                      ENG    624
#
#                                      Best Performance
# 0                                   816 v Banglade...
# 1                                   797 v West Ind...
# 2                                   821 v West Ind...
# 3                                   806 v Sri Lank...
# 4                                   745 v Ireland,...
# 5                                   665 v New Zeal...
# 6                                   743 v Sri Lank...
# 7                                   695 v India, 1...
# 8                                   680 v Pakistan...
# 9                                   731 v Pakistan...
# 10                                  682 v Afghanis...
# 11                                  746 v West Ind...
# 12                                  653 v Sri Lank...
# 13                                  662 v India, 0...
# 14                                  681 v India, 0...
# 15                                  669 v Banglade...
# 16                                  632 v Netherla...
# 17                                  765 v Sri Lank...
# 18                                  769 v Scotland...
# 19                                  662 v Australi...

# %%
df.tail(20)
# Out:
#             Players Name Team Name Rating  \
# 80             J.J. Smit       NAM    427
# 81          Hasan Mahmud       BAN    415
# 82         Hardik Pandya       IND    413
# 83  Wellington Masakadza       ZIM    411
# 84            Khawar Ali       OMA    410
# 85  Palaniapan Meiyappan       UAE    407
# 86     Ruben Trumpelmann       NAM    406
# 87         Rohan Mustafa       UAE    404
# 88           Fayyaz Butt       OMA    403
# 89        Alasdair Evans       SCO    400
# 90            Josh Davey       SCO    399
# 91            Avesh Khan       IND    394
# 92            Adam Milne        NZ    394
# 93            Ahmed Raza       UAE    393
# 94        Mohammad Shami       IND    392
# 95  Roelof van der Merwe       NED    391
# 96          Fabian Allen        WI    387
# 97          Nathan Ellis       AUS    384
# 98        Barry McCarthy       IRE    384
# 99         Sean Williams       ZIM    384
#
#                                      Best Performance
# 80                                  472 v Afghanis...
# 81                                  415 v Zimbabwe...
# 82                                  545 v South Af...
# 83                                  469 v Ireland,...
# 84                                  530 v Canada, ...
# 85                                  407 v Namibia,...
# 86                                  406 v UAE, 20/...
# 87                                  499 v Hong Kon...
# 88                                  413 v Canada, ...
# 89                                  598 v Netherla...
# 90                                  442 v Oman, 21...
# 91                                  458 v West Ind...
# 92                                  661 v Pakistan...
# 93                                  578 v Papua Ne...
# 94                                  392 v South Af...
# 95                                  516 v Papua Ne...
# 96                                  625 v Australi...
# 97                                  404 v England,...
# 98                                  384 v Australi...
# 99                                  506 v Afghanis...

# %%
df.iloc[50:75]
# Out:
#                Players Name Team Name Rating  \
# 50        Michael Bracewell        NZ    499
# 51           Alzarri Joseph        WI    494
# 52          Bernard Scholtz       NAM    484
# 53             David Willey       ENG    484
# 54            Lahiru Kumara        SL    482
# 55          Richard Ngarava       ZIM    479
# 56              David Wiese       NAM    479
# 57      Chamika Karunaratne        SL    479
# 58              Zahoor Khan       UAE    476
# 59              Naseem Shah       PAK    474
# 60             Naveen Murid       AFG    473
# 61             Taskin Ahmed       BAN    470
# 62      Dushmantha Chameera        SL    469
# 63               Mark Adair       IRE    463
# 64        Paul van Meekeren       NED    459
# 65  Mohammad Shoriful Islam       BAN    456
# 66             Ravi Bishnoi       IND    454
# 67           Tendai Chatara       ZIM    454
# 68             Jan Frylinck       NAM    452
# 69             Hayden Walsh        WI    452
# 70           Jasprit Bumrah       IND    450
# 71          Kane Richardson       AUS    450
# 72            Deepak Chahar       IND    449
# 73       Sandeep Lamichhane       NEP    447
# 74              Odean Smith        WI    446
#
#                                      Best Performance
# 50                                  514 v Pakistan...
# 51                                  494 v Ireland,...
# 52                                  484 v UAE, 20/...
# 53                                  640 v West Ind...
# 54                                  493 v India, 2...
# 55                                  501 v Scotland...
# 56                                  646 v South Af...
# 57                                  498 v Australi...
# 58                                  476 v Namibia,...
# 59                                  474 v Netherla...
# 60                                  492 v Sri Lank...
# 61                                  470 v Zimbabwe...
# 62                                  555 v India, 2...
# 63                                  573 v Namibia,...
# 64                                  552 v Ireland,...
# 65                                  513 v West Ind...
# 66                                  507 v Pakistan...
# 67                                  477 v Singapor...
# 68                                  482 v Scotland...
# 69                                  528 v Pakistan...
# 70                                  764 v England,...
# 71                                  664 v England,...
# 72                                  581 v West Ind...
# 73                                  512 v Papua Ne...
# 74                                  460 v Zimbabwe...

# %%
df.sample(10)
# Out:
#           Players Name Team Name Rating  \
# 22         Ashton Agar       AUS    595
# 49         Pat Cummins       AUS    505
# 93          Ahmed Raza       UAE    393
# 3       Josh Hazlewood       AUS    692
# 61        Taskin Ahmed       BAN    470
# 73  Sandeep Lamichhane       NEP    447
# 18         Shadab Khan       PAK    624
# 66        Ravi Bishnoi       IND    454
# 86   Ruben Trumpelmann       NAM    406
# 74         Odean Smith        WI    446
#
#                                      Best Performance
# 22                                  717 v England,...
# 49                                  610 v England,...
# 93                                  578 v Papua Ne...
# 3                                   806 v Sri Lank...
# 61                                  470 v Zimbabwe...
# 73                                  512 v Papua Ne...
# 18                                  769 v Scotland...
# 66                                  507 v Pakistan...
# 86                                  406 v UAE, 20/...
# 74                                  460 v Zimbabwe...

# %% [markdown]
# # Q11. Scrap ICC Men's T20 All Rounder and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/t20i/all-rounder"
page11 = requests.get(url)

# Check page content
soup = BeautifulSoup(page11.content)

# %%
# Create empty list and store data:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all('div', class_ = 'rankings-block__banner--name-large'):
    players.append(i.text)
    
for i in soup.find_all('div', class_ = 'rankings-block__banner--nationality'):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all('div', class_ = 'rankings-block__banner--rating'):
    rating.append(i.text)
    
for i in soup.find_all('span', class_ = 'rankings-block__career-best-text'):
    best.append(i.text.replace('\n', ''))
    
for i in soup.find_all('td', class_ = 'table-body__cell rankings-table__name name'):
    for u in i.find_all('a'):
        players.append(u.text)
        
for i in soup.find_all('span', class_ = 'table-body__logo-text'):
    team_name.append(i.text)
    
for i in soup.find_all('td', class_ = 'table-body__cell rating'):
    rating.append(i.text)
    
for i in soup.find_all('td', class_ = 'table-body__cell u-text-right u-hide-phablet'):
    best.append(i.text.replace('\n', ''))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 20 20 20 20

# %% [markdown]
# # Create a Data Frame

# %%
T20_All_Rounser = pd.DataFrame({})
T20_All_Rounser['Player Name'] = players
T20_All_Rounser['Team Name'] = team_name
T20_All_Rounser['Rating'] = rating
T20_All_Rounser['Best Performance'] = best
T20_All_Rounser
# Out:
#           Player Name                Team Name Rating  \
# 0     Shakib Al Hasan  BAN                        255
# 1       Mohammad Nabi                      AFG    244
# 2       Hardik Pandya                      IND    182
# 3           Moeen Ali                      ENG    175
# 4           J.J. Smit                      NAM    174
# 5       Sikandar Raza                      ZIM    172
# 6         David Wiese                      NAM    170
# 7   Wanindu Hasaranga                       SL    165
# 8      Marcus Stoinis                      AUS    164
# 9       Glenn Maxwell                      AUS    159
# 10    Zeeshan Maqsood                      OMA    158
# 11      Sean Williams                      ZIM    157
# 12     Dipendra Airee                      NEP    151
# 13      Aiden Markram                       SA    144
# 14   Liam Livingstone                      ENG    142
# 15      Rohan Mustafa                      UAE    141
# 16    Gerhard Erasmus                      NAM    139
# 17      Charles Amini                      PNG    127
# 18       Norman Vanua                      PNG    122
# 19     Mohammad Nawaz                      PAK    119
#
#                                      Best Performance
# 0                                   408 v Pakistan...
# 1                                   355 v Banglade...
# 2                                   189 v Pakistan...
# 3                                   221 v South Af...
# 4                                   185 v Afghanis...
# 5                                   184 v Scotland...
# 6                                   170 v UAE, 20/...
# 7                                   184 v Pakistan...
# 8                                   164 v Ireland,...
# 9                                   397 v Sri Lank...
# 10                                  180 v Scotland...
# 11                                  232 v Nepal, 0...
# 12                                  161 v Kenya, 2...
# 13                                  158 v England,...
# 14                                  179 v New Zeal...
# 15                                  182 v Jersey, ...
# 16                                  144 v Netherla...
# 17                                  140 v Nepal, 3...
# 18                                  155 v Singapor...
# 19                                  122 v Zimbabwe...

# %% [markdown]
# # Q12. Scrap ICC Men's Test Team and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/test"
page12 = requests.get(url)

# Check page content
soup = BeautifulSoup(page12.content)

# %%
# Create empty list and store data:
team = soup.find_all('span', class_ = 'u-hide-phablet')
team_name = []
for i in team:
    team_name.append(i.text)

# %%
matches = []
points = []
rating = []
new_list = []

for i in soup.find_all('td', class_ = 'rankings-block__banner--matches'):
    matches.append(i.text)
    
for i in soup.find_all('td', class_ = 'rankings-block__banner--points'):
    points.append(i.text)
    
for i in soup.find_all('td', class_ = 'rankings-block__banner--rating u-text-right'):
    rating.append(i.text.replace('\n', ''))
    
for i in soup.find_all('td', class_ = 'table-body__cell u-center-text'):
    new_list.append(i.text)
    
for i in range(0, len(new_list)-1,2):
    matches.append(new_list[i])
    points.append(new_list[i+1])
    
for i in soup.find_all('td', class_ = 'table-body__cell u-text-right rating'):
    rating.append(i.text)

# %%
print(len(team_name), len(matches), len(points), len(rating))
# Out:
# 10 10 10 10

# %% [markdown]
# # Create a Data Frame

# %%
Test = pd.DataFrame({})
Test['Team Name'] = team_name
Test['Matches'] = matches
Test['Points'] = points
Test['Rating'] = rating
Test
# Out:
#       Team Name Matches Points  \
# 0     Australia      19  2,439
# 1         India      29  3,318
# 2  South Africa      25  2,606
# 3       England      43  4,449
# 4   New Zealand      27  2,704
# 5      Pakistan      23  2,111
# 6     Sri Lanka      23  1,916
# 7   West Indies      25  1,988
# 8    Bangladesh      22  1,047
# 9      Zimbabwe       6    148
#
#                                               Rating
# 0                              128               ...
# 1                                                114
# 2                                                104
# 3                                                103
# 4                                                100
# 5                                                 92
# 6                                                 83
# 7                                                 80
# 8                                                 48
# 9                                                 25

# %% [markdown]
# # Q13. Scrap ICC Men's Test Batsmen and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/test/batting"
page13 = requests.get(url)

# Check page content
soup = BeautifulSoup(page13.content)

# %%
# Create empty list and store data:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all('div', class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all('div', class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all('div', class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all('span', class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace('\n', ""))
    
for i in soup.find_all('td', class_ = "table-body__cell rankings-table__name name"):
    for l in i.find_all('a'):
        players.append(l.text)
        
for i in soup.find_all('span', class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace('\n', ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create a Data Frame

# %%
test_players = pd.DataFrame({})
test_players['Players Name'] = players
test_players['Teame Name'] = team_name
test_players['Rating'] = rating
test_players['Best Performance'] = best
test_players
# Out:
#           Players Name               Teame Name Rating  \
# 0             Joe Root  ENG                        887
# 1   Marnus Labuschagne                      AUS    885
# 2           Babar Azam                      PAK    879
# 3          Steve Smith                      AUS    848
# 4         Rishabh Pant                      IND    801
# ..                 ...                      ...    ...
# 95        Dan Lawrence                      ENG    377
# 96        Haris Sohail                      PAK    369
# 97      Shamarh Brooks                       WI    369
# 98        Roston Chase                       WI    369
# 99      Mitchell Starc                      AUS    362
#
#                                      Best Performance
# 0                                   923 v India, 0...
# 1                                   936 v Pakistan...
# 2                                   879 v Sri Lank...
# 3                                   947 v England,...
# 4                                   801 v England,...
# ..                                                ...
# 95                                  442 v West Ind...
# 96                                  563 v New Zeal...
# 97                                  536 v England,...
# 98                                  626 v Pakistan...
# 99                                  446 v India, 2...
#
# [100 rows x 4 columns]

# %%
df = test_players
df.head(15)
# Out:
#           Players Name               Teame Name Rating  \
# 0             Joe Root  ENG                        887
# 1   Marnus Labuschagne                      AUS    885
# 2           Babar Azam                      PAK    879
# 3          Steve Smith                      AUS    848
# 4         Rishabh Pant                      IND    801
# 5      Kane Williamson                       NZ    786
# 6        Usman Khawaja                      AUS    766
# 7   Dimuth Karunaratne                       SL    748
# 8         Rohit Sharma                      IND    746
# 9       Jonny Bairstow                      ENG    719
# 10      Daryl Mitchell                       NZ    715
# 11         Virat Kohli                      IND    714
# 12          Litton Das                      BAN    694
# 13         Travis Head                      AUS    678
# 14    Dinesh Chandimal                       SL    673
#
#                                      Best Performance
# 0                                   923 v India, 0...
# 1                                   936 v Pakistan...
# 2                                   879 v Sri Lank...
# 3                                   947 v England,...
# 4                                   801 v England,...
# 5                                   919 v Pakistan...
# 6                                   779 v Sri Lank...
# 7                                   782 v Australi...
# 8                                   813 v England,...
# 9                                   772 v South Af...
# 10                                  715 v England,...
# 11                                  937 v England,...
# 12                                  724 v Sri Lank...
# 13                                  773 v England,...
# 14                                  755 v West Ind...

# %%
df.tail()
# Out:
#       Players Name Teame Name Rating  \
# 95    Dan Lawrence        ENG    377
# 96    Haris Sohail        PAK    369
# 97  Shamarh Brooks         WI    369
# 98    Roston Chase         WI    369
# 99  Mitchell Starc        AUS    362
#
#                                      Best Performance
# 95                                  442 v West Ind...
# 96                                  563 v New Zeal...
# 97                                  536 v England,...
# 98                                  626 v Pakistan...
# 99                                  446 v India, 2...

# %%
df.sample(20)
# Out:
#              Players Name Teame Name Rating  \
# 15        Mohammad Rizwan        PAK    670
# 17             Dean Elgar         SA    665
# 88    Hashmatullah Shaidi        AFG    397
# 45  Rassie van der Dussen         SA    547
# 48     Niroshan Dickwella         SL    534
# 81      Lahiru Thirimanne         SL    419
# 16           David Warner        AUS    667
# 96           Haris Sohail        PAK    369
# 29         Henry Nicholls         NZ    613
# 30               Abid Ali        PAK    610
# 14       Dinesh Chandimal         SL    673
# 44           Lokesh Rahul        IND    560
# 58             Rory Burns        ENG    500
# 61         Ibrahim Zadran        AFG    486
# 59             Alex Carey        AUS    497
# 25             Tom Latham         NZ    622
# 33    Colin de Grandhomme         NZ    601
# 79         Kyle Verreynne         SA    428
# 98           Roston Chase         WI    369
# 1      Marnus Labuschagne        AUS    885
#
#                                      Best Performance
# 15                                  700 v Australi...
# 17                                  784 v Australi...
# 88                                  397 v Zimbabwe...
# 45                                  557 v New Zeal...
# 48                                  595 v Zimbabwe...
# 81                                  498 v Banglade...
# 16                                  880 v India, 1...
# 96                                  563 v New Zeal...
# 29                                  778 v Banglade...
# 30                                  643 v Banglade...
# 14                                  755 v West Ind...
# 44                                  761 v Sri Lank...
# 58                                  661 v West Ind...
# 61                                  486 v Zimbabwe...
# 59                                  497 v Sri Lank...
# 25                                  733 v West Ind...
# 33                                  613 v England,...
# 79                                  456 v England,...
# 98                                  626 v Pakistan...
# 1                                   936 v Pakistan...

# %%
df.iloc[35:55]
# Out:
#              Players Name Teame Name Rating  \
# 35        Ravindra Jadeja        IND    590
# 36           Shreyas Iyer        IND    585
# 37     Jermaine Blackwood         WI    583
# 38         Ajinkya Rahane        IND    577
# 39          Cameron Green        AUS    576
# 40            Tamim Iqbal        BAN    572
# 41    Dhananjaya de Silva         SL    570
# 42        Shakib Al Hasan        BAN    570
# 43        Keegan Petersen         SA    569
# 44           Lokesh Rahul        IND    560
# 45  Rassie van der Dussen         SA    547
# 46             Fawad Alam        PAK    536
# 47            Zak Crawley        ENG    535
# 48     Niroshan Dickwella         SL    534
# 49            Imam-ul-Haq        PAK    523
# 50          Sikandar Raza        ZIM    523
# 51          Aiden Markram         SA    522
# 52          Nkruma Bonner         WI    516
# 53           Kusal Mendis         SL    516
# 54            Kyle Mayers         WI    511
#
#                                      Best Performance
# 35                                  590 v England,...
# 36                                  585 v England,...
# 37                                  596 v Banglade...
# 38                                  825 v New Zeal...
# 39                                  607 v Sri Lank...
# 40                                  709 v Australi...
# 41                                  636 v West Ind...
# 42                                  694 v Australi...
# 43                                  597 v India, 1...
# 44                                  761 v Sri Lank...
# 45                                  557 v New Zeal...
# 46                                  648 v Australi...
# 47                                  605 v Pakistan...
# 48                                  595 v Zimbabwe...
# 49                                  523 v Sri Lank...
# 50                                  547 v West Ind...
# 51                                  759 v Australi...
# 52                                  631 v England,...
# 53                                  693 v West Ind...
# 54                                  526 v Sri Lank...

# %% [markdown]
# # Q14. Scrap ICC Men's Test Bowlers and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/test/bowling"
page14 = requests.get(url)

# Check page content
soup = BeautifulSoup(page14.content)

# %%
# Create empty list and store data:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all('div', class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all('div', class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all('div', class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all('span', class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace('\n', ""))
    
for i in soup.find_all('td', class_ = "table-body__cell rankings-table__name name"):
    for l in i.find_all('a'):
        players.append(l.text)
        
for i in soup.find_all('span', class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace('\n', ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 100 100 100 100

# %% [markdown]
# # Create a Data Frame

# %%
test_bowlers = pd.DataFrame({})
test_bowlers['Bowler Name'] = players
test_bowlers['Teame Name'] = team_name
test_bowlers['Rating'] = rating
test_bowlers['Best Performance'] = best
test_bowlers
# Out:
#             Bowler Name               Teame Name Rating  \
# 0           Pat Cummins  AUS                        891
# 1   Ravichandran Ashwin                      IND    842
# 2        Shaheen Afridi                      PAK    828
# 3        Jasprit Bumrah                      IND    828
# 4        James Anderson                      ENG    825
# ..                  ...                      ...    ...
# 95        Dasun Shanaka                       SL    190
# 96     Mitchell Swepson                      AUS    187
# 97          Mahmudullah                      BAN    185
# 98        Saqib Mahmood                      ENG    182
# 99        Sean Williams                      ZIM    181
#
#                                      Best Performance
# 0                                   914 v England,...
# 1                                   904 v England,...
# 2                                   836 v Sri Lank...
# 3                                   835 v West Ind...
# 4                                   903 v India, 1...
# ..                                                ...
# 95                                  269 v India, 2...
# 96                                  187 v Sri Lank...
# 97                                  381 v West Ind...
# 98                                  195 v West Ind...
# 99                                  247 v Banglade...
#
# [100 rows x 4 columns]

# %%
df = test_bowlers
df.head(20)
# Out:
#             Bowler Name               Teame Name Rating  \
# 0           Pat Cummins  AUS                        891
# 1   Ravichandran Ashwin                      IND    842
# 2        Shaheen Afridi                      PAK    828
# 3        Jasprit Bumrah                      IND    828
# 4        James Anderson                      ENG    825
# 5         Kagiso Rabada                       SA    799
# 6         Kyle Jamieson                       NZ    788
# 7           Kemar Roach                       WI    756
# 8           Neil Wagner                       NZ    747
# 9        Mitchell Starc                      AUS    739
# 10          Trent Boult                       NZ    739
# 11       Josh Hazlewood                      AUS    737
# 12         Stuart Broad                      ENG    734
# 13          Tim Southee                       NZ    706
# 14       Ollie Robinson                      ENG    691
# 15          Nathan Lyon                      AUS    683
# 16       Mohammad Shami                      IND    670
# 17            Hasan Ali                      PAK    669
# 18         Jason Holder                       WI    665
# 19       Mohammad Abbas                      PAK    657
#
#                                      Best Performance
# 0                                   914 v England,...
# 1                                   904 v England,...
# 2                                   836 v Sri Lank...
# 3                                   835 v West Ind...
# 4                                   903 v India, 1...
# 5                                   902 v Australi...
# 6                                   836 v England,...
# 7                                   780 v India, 0...
# 8                                   859 v Australi...
# 9                                   806 v New Zeal...
# 10                                  825 v England,...
# 11                                  863 v India, 0...
# 12                                  880 v South Af...
# 13                                  839 v India, 2...
# 14                                  691 v South Af...
# 15                                  774 v England,...
# 16                                  790 v Banglade...
# 17                                  760 v Banglade...
# 18                                  862 v England,...
# 19                                  838 v New Zeal...

# %%
df.tail(10)
# Out:
#          Bowler Name Teame Name Rating  \
# 90  Mitchell Santner         NZ    217
# 91     Craig Overton        ENG    216
# 92      Haris Sohail        PAK    208
# 93      George Linde         SA    201
# 94      Taskin Ahmed        BAN    193
# 95     Dasun Shanaka         SL    190
# 96  Mitchell Swepson        AUS    187
# 97       Mahmudullah        BAN    185
# 98     Saqib Mahmood        ENG    182
# 99     Sean Williams        ZIM    181
#
#                                      Best Performance
# 90                                  344 v West Ind...
# 91                                  256 v India, 2...
# 92                                  298 v Banglade...
# 93                                  227 v Pakistan...
# 94                                  221 v New Zeal...
# 95                                  269 v India, 2...
# 96                                  187 v Sri Lank...
# 97                                  381 v West Ind...
# 98                                  195 v West Ind...
# 99                                  247 v Banglade...

# %%
df.iloc[60:80]
# Out:
#              Bowler Name Teame Name Rating  \
# 60            Nauman Ali        PAK    347
# 61  Praveen Jayawickrama         SL    343
# 62        Jomel Warrican         WI    329
# 63       Vishwa Fernando         SL    328
# 64          Simon Harmer         SA    325
# 65          Jofra Archer        ENG    323
# 66          Dominic Bess        ENG    321
# 67        Mohammad Nawaz        PAK    316
# 68         Sikandar Raza        ZIM    315
# 69         Kuldeep Yadav        IND    315
# 70            Sam Curran        ENG    305
# 71      Rahkeem Cornwall         WI    297
# 72         Faheem Ashraf        PAK    283
# 73         Cameron Green        AUS    283
# 74            Sajid Khan        PAK    279
# 75       Jhye Richardson        AUS    275
# 76         Willem Mulder         SA    273
# 77             Abu Jayed        BAN    270
# 78         Yamin Ahmadzi        AFG    260
# 79    Veerasammy Permaul         WI    257
#
#                                      Best Performance
# 60                                  420 v West Ind...
# 61                                  472 v India, 1...
# 62                                  346 v Sri Lank...
# 63                                  402 v Banglade...
# 64                                  391 v Banglade...
# 65                                  465 v Australi...
# 66                                  439 v India, 0...
# 67                                  316 v Sri Lank...
# 68                                  340 v Sri Lank...
# 69                                  402 v Australi...
# 70                                  421 v Sri Lank...
# 71                                  376 v Sri Lank...
# 72                                  292 v South Af...
# 73                                  338 v England,...
# 74                                  415 v Banglade...
# 75                                  298 v England,...
# 76                                  360 v Sri Lank...
# 77                                  374 v West Ind...
# 78                                  360 v Banglade...
# 79                                  287 v Sri Lank...

# %%
df.sample(10)
# Out:
#            Bowler Name Teame Name Rating  \
# 84          Olly Stone        ENG    244
# 11      Josh Hazlewood        AUS    737
# 38         Umesh Yadav        IND    537
# 67      Mohammad Nawaz        PAK    316
# 8          Neil Wagner         NZ    747
# 83      Victor Nyauchi        ZIM    247
# 90    Mitchell Santner         NZ    217
# 5        Kagiso Rabada         SA    799
# 35  Prabath Jayasuriya         SL    550
# 87            Joe Root        ENG    227
#
#                                      Best Performance
# 84                                  295 v New Zeal...
# 11                                  863 v India, 0...
# 38                                  672 v Banglade...
# 67                                  316 v Sri Lank...
# 8                                   859 v Australi...
# 83                                  327 v Afghanis...
# 90                                  344 v West Ind...
# 5                                   902 v Australi...
# 35                                  550 v Pakistan...
# 87                                  251 v Australi...

# %% [markdown]
# # Q15. Scrap ICC Men's Test All Rounder and Create a Data Frame

# %%
# Send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/test/all-rounder"
page15 = requests.get(url)

# Check page content
soup = BeautifulSoup(page15.content)

# %%
# Create empty list and store data:
players = []
team_name = []
rating = []
best = []

for i in soup.find_all('div', class_ = "rankings-block__banner--name-large"):
    players.append(i.text)
    
for i in soup.find_all('div', class_ = "rankings-block__banner--nationality"):
    team_name.append(i.text.replace('\n', ''))
    
for i in soup.find_all('div', class_ = "rankings-block__banner--rating"):
    rating.append(i.text)
    
for i in soup.find_all('span', class_ = "rankings-block__career-best-text"):
    best.append(i.text.replace('\n', ""))
    
for i in soup.find_all('td', class_ = "table-body__cell rankings-table__name name"):
    for l in i.find_all('a'):
        players.append(l.text)
        
for i in soup.find_all('span', class_ = "table-body__logo-text"):
    team_name.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell rating"):
    rating.append(i.text)
    
for i in soup.find_all('td', class_ = "table-body__cell u-text-right u-hide-phablet"):
    best.append(i.text.replace('\n', ""))

# %%
print(len(players), len(team_name), len(rating), len(best))
# Out:
# 20 20 20 20

# %% [markdown]
# # Create a Data Frame

# %%
test_allrounder = pd.DataFrame({})
test_allrounder['Bowler Name'] = players
test_allrounder['Teame Name'] = team_name
test_allrounder['Rating'] = rating
test_bowlers['Best Performance'] = best
test_bowlers
